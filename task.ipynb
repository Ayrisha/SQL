# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Просмотр данных

# %%
df =  pd.read_csv('result.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  course_id                                        course_name  \
# 0           0        101  Курс "Кульный" по итоговому сочинению 2к24 для...
# 1           1         40                                     НЕдетский курс
# 2           2        101  Курс "Кульный" по итоговому сочинению 2к24 для...
# 3           3        102         Курс "Кульный" по итоговому сочинению 2к24
# 4           4         88                                     Морфология PRO
# 5           5         19                              Годовой 2к25 стандарт
# 6           6         42                                  Годовой курс 2к25
# 7           7         17                              Годовой 2к25 стандарт
# 8           8         16                              Годовой 2к25 стандарт
# 9           9         17                              Годовой 2к25 стандарт
#
#       subject_name subject_type course_type course_starts_at  user_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14373 entries, 0 to 14372
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 14373 non-null  int64
#  1   course_id                  14373 non-null  int64
#  2   course_name                14373 non-null  object
#  3   subject_name               14373 non-null  object
#  4   subject_type               14373 non-null  object
#  5   course_type                14373 non-null  object
#  6   course_starts_at           14373 non-null  object
#  7   user_id                    14373 non-null  int64
#  8   user_last_name             14373 non-null  object
#  9   city_name                  14373 non-null  object
#  10  active                     14373 non-null  int64
#  11  course_created_at          14373 non-null  object
#  12  available_months           5997 non-null   float64
# ...

# %%
df.isnull().sum()

# %%
sns.countplot(data = df, x = "available_months")
# Out:
# <Axes: xlabel='available_months', ylabel='count'>
